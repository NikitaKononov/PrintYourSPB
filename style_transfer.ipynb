# %%
# GAN
# !gdown 11sbuCUaxByXTJ3N9QbjPIvT8C_jFXkUj
# !unzip fast_neural_style

# dataset
# !gdown 1zpDszJsKMP-Gwe-my-unFeJhjSIiJQnz
# !unzip img_dataset
# !mkdir train_ds
# !mv img_dataset train_ds

# Папка с картинками, чтобы обучить модель с новым стилем
# !gdown 1-1X-BFZyiNHvzBe4B0dZAgEQVunxWL_P
# !unzip styles

# Готовые модели со стилями
# !gdown 1s55Q18tNycdnFVmMGvMoLnqniGYZ1sqX
# !unzip saved_models

# create folders
# !mkdir results

# %% [markdown]
# # Закинитье свою картинку и пропишите к ней путь ниже

# %% [markdown]
# ## Применение стиля

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# применить какой-то стиль из папка saved_models
# !python /content/fast_neural_style/neural_style/neural_style.py eval --content-image /content/5.webp --model /content/saved_models/mosaiq.pth --output-image /content/results/6.jpg --cuda 0


# !python /content/fast_neural_style/neural_style/neural_style.py eval --content-image /content/5.jpeg --model /content/saved_models/style_4/epoch_20_Thu_Sep__8_09:14:27_2022_100000.0_10000000000.0.model --output-image /content/results/4.jpg --cuda 0

# %% [markdown]
# ## Обучение стилю

# %% [markdown]
# ![image.png](data:image/png;base64,...)![image.png]()

# %%
# обучение модели: создание файла.pth (или .model) в папке saved_models
# лучше его переименовать нормально
# !python /content/fast_neural_style/neural_style/neural_style.py train --dataset /content/train_ds/ --style-image /content/styles/style_4.jpg --save-model-dir /content/saved_models/style_4 --epochs 20 --cuda 1
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and will be removed in 0.15, "
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
#
# Done, trained model saved at /content/saved_models/style_4/epoch_20_Thu_Sep__8_09:14:27_2022_100000.0_10000000000.0.model
